# %% [markdown]
# # MNIST image recognition

# %%
# Import the modules
import numpy as np
import cv2
#import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im = cv2.imread("./images/prueba4.jpg")
print(im.shape)
plt.imshow(im, cmap='gray')
#plt.show()
# Out:
# (176L, 1324L, 3L)

# %%
# Convert to grayscale and apply Gaussian filtering
im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
im_gray = cv2.GaussianBlur(im_gray, (5, 5), 0)
plt.imshow(im_gray)

# %%
# Blurred
edged = cv2.Canny(im_gray, 30, 150)
plt.imshow(edged)

# %%
# Threshold the image
ret, im_th = cv2.threshold(im_gray, 60, 255, cv2.THRESH_BINARY_INV)
plt.imshow(im_th)

# %%
# Find contours in the image
_, ctrs, hier = cv2.findContours(im_th.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# Get rectangles contains each contour
rects = [cv2.boundingRect(ctr) for ctr in ctrs]
print(rects)
# Out:
# [(1142, 48, 32, 56), (1067, 48, 21, 56), (1019, 48, 37, 56), (985, 48, 21, 55), (937, 48, 38, 55), (856, 48, 36, 55), (1100, 47, 36, 57), (904, 47, 20, 56), (814, 47, 36, 57), (773, 47, 38, 57), (691, 47, 37, 56), (650, 47, 38, 56), (610, 47, 35, 56), (567, 47, 39, 56), (530, 47, 32, 56), (487, 47, 36, 56), (364, 47, 36, 56), (322, 47, 38, 56), (281, 47, 37, 56), (239, 47, 36, 56), (207, 47, 19, 56), (731, 46, 39, 58), (403, 46, 80, 58)]

# %%
i=1
for rect in rects:
    # Draw the rectangles
    cv2.rectangle(im, (rect[0], rect[1]), (rect[0] + rect[2], rect[1] + rect[3]), (0, 255, 0), 3) 
    # Make the rectangular region around the digit
    leng = int(rect[3] * 1.6)
    pt1 = int(rect[1] + rect[3] // 2 - leng // 2)
    pt2 = int(rect[0] + rect[2] // 2 - leng // 2)
    roi = im_th[pt1:pt1+leng, pt2:pt2+leng]
    
    print(" Roi {}".format(i))
    i = i + 1
    # Resize the image
    #roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
    #roi = cv2.dilate(roi, (3, 3))
    # Calculate the HOG features
    #roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), visualise=False)

# %%
plt.imshow(im)

# %%
## Guarda resultados
cv2.imwrite('./results/res_p4.png',im)
# Out:
# True
